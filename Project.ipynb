# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub as path

# %%
pip install pillow
# Out:
#   Cell In[5], line 1
#     pip install pillow
#         ^
# SyntaxError: invalid syntax

# %%
from IPython.display import Image, display

url = "https://storage.googleapis.com/kaggle-datasets-images/3802467/6587269/5ca5f313e27b4daf789ab8fc333079ca/dataset-card.png?t=2023-10-01-18-08-22"
display(Image(url=url))
# Out:
# <img src="https://storage.googleapis.com/kaggle-datasets-images/3802467/6587269/5ca5f313e27b4daf789ab8fc333079ca/dataset-card.png?t=2023-10-01-18-08-22"/>

# %%
#Load the dataset into a pandas DataFrame.
import kagglehub
import os 
import pandas as pd
# Download latest version
path = kagglehub.dataset_download("anassarfraz13/coffee-sales-dataset",)

file_path = os.path.join(path, 'Coffe_sales.csv')
df = pd.read_csv(file_path)

df
# Out:
# ...
# 100%|██████████| 38.1k/38.1k [00:00<00:00, 433kB/s]
# Extracting files...
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
# ...

# %%
#Load the dataset into a pandas DataFrame.
df.dropna()  #Handle missing values (drop or fill)
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.fillna(0,inplace=True) #Replace NaN
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.dropna(axis=1) #Remove unnecessary columns
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.select_dtypes(include = ["number","category"]).corr() #Convert columns to correct data types (numeric, categorical)
# Out:
#              hour_of_day     money  Weekdaysort  Monthsort
# hour_of_day     1.000000  0.202748    -0.002614   0.008293
# money           0.202748  1.000000    -0.017264  -0.050043
# Weekdaysort    -0.002614 -0.017264     1.000000   0.044141
# Monthsort       0.008293 -0.050043     0.044141   1.000000

# %%
df.info() #Show dataset info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3547 entries, 0 to 3546
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  3547 non-null   int64
#  1   cash_type    3547 non-null   object
#  2   money        3547 non-null   float64
#  3   coffee_name  3547 non-null   object
#  4   Time_of_Day  3547 non-null   object
#  5   Weekday      3547 non-null   object
#  6   Month_name   3547 non-null   object
#  7   Weekdaysort  3547 non-null   int64
#  8   Monthsort    3547 non-null   int64
#  9   Date         3547 non-null   object
#  10  Time         3547 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 304.9+ KB

# %%
df.describe() #descriptive statistics
# Out:
#        hour_of_day        money  Weekdaysort    Monthsort
# count  3547.000000  3547.000000  3547.000000  3547.000000
# mean     14.185791    31.645216     3.845785     6.453905
# std       4.234010     4.877754     1.971501     3.500754
# min       6.000000    18.120000     1.000000     1.000000
# 25%      10.000000    27.920000     2.000000     3.000000
# 50%      14.000000    32.820000     4.000000     7.000000
# 75%      18.000000    35.760000     6.000000    10.000000
# max      22.000000    38.700000     7.000000    12.000000

# %%
df.value_counts() #Count unique values in categorical columns
# Out:
# hour_of_day  cash_type  money  coffee_name          Time_of_Day  Weekday  Month_name  Weekdaysort  Monthsort  Date        Time
# 22           card       37.72  Latte                Night        Fri      May         5            5          2024-05-17  22:37:42.821000    1
# 6            card       25.96  Americano            Morning      Fri      Feb         5            2          2025-02-21  06:59:08.408000    1
#                                                                  Mon      Mar         1            3          2025-03-17  06:54:40.633000    1
#                         30.86  Americano with Milk  Morning      Fri      Feb         5            2          2025-02-28  06:52:45.591000    1
#                                                                                                                           06:54:59.973000    1
#                                                                                                                                             ..
# ...

# %%
df.columns
# Out:
# Index(['hour_of_day', 'cash_type', 'money', 'coffee_name', 'Time_of_Day',
#        'Weekday', 'Month_name', 'Weekdaysort', 'Monthsort', 'Date', 'Time'],
#       dtype='object')

# %%
category = (['hour_of_day', 'cash_type', 'money', 'coffee_name', 'Time_of_Day',
       'Weekday', 'Month_name', 'Weekdaysort', 'Monthsort', 'Date', 'Time])
# Out:
#   Cell In[17], line 2
#     'Weekday', 'Month_name', 'Weekdaysort', 'Monthsort', 'Date', 'Time])
#                                                                  ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
df.mean
# Out:
# <bound method DataFrame.mean of       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.max
# Out:
# <bound method DataFrame.max of       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.min
# Out:
# <bound method DataFrame.min of       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.loc[]
# Out:
#   Cell In[21], line 1
#     df.loc[]
#            ^
# SyntaxError: invalid syntax

# %%
df["cash_type"].value_counts()
# Out:
# cash_type
# card    3547
# Name: count, dtype: int64

# %%
df["coffee_name"].value_counts()
# Out:
# coffee_name
# Americano with Milk    809
# Latte                  757
# Americano              564
# Cappuccino             486
# Cortado                287
# Hot Chocolate          276
# Cocoa                  239
# Espresso               129
# Name: count, dtype: int64

# %%
df["Time_of_Day"].value_counts()
# Out:
# Time_of_Day
# Afternoon    1205
# Morning      1181
# Night        1161
# Name: count, dtype: int64

# %%
df["Weekday"].value_counts()
# Out:
# Weekday
# Tue    572
# Mon    544
# Fri    532
# Thu    510
# Wed    500
# Sat    470
# Sun    419
# Name: count, dtype: int64

# %%
df["Month_name"].value_counts()
# Out:
# Month_name
# Mar    494
# Oct    426
# Feb    423
# Sep    344
# Aug    272
# Dec    259
# Nov    259
# May    241
# Jul    237
# Jun    223
# Jan    201
# Apr    168
# Name: count, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %%
df["hour_of_day"].mean()
# Out:
# np.float64(14.18579080913448)

# %%
df["money"].mean()
# Out:
# np.float64(31.64521567521849)

# %%
df["Weekdaysort"].mean()
# Out:
# np.float64(3.845785170566676)

# %%
df["Monthsort"].mean()
# Out:
# np.float64(6.453904708204116)
